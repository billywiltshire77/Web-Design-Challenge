# %%
import pandas as pd
import os

# %%
file = 'assets/cities.csv'

# %%
df = pd.read_csv(file)
df.head()
# Out:
#    Unnamed: 0             City Country  Longitude  Latitude  Humidity (%)  \
# 0           0  Severo-Kuril'sk      RU     156.12     50.68            74
# 1           1           Carora      VE     -70.08     10.18            51
# 2           2             Hilo      US    -155.09     19.73            92
# 3           3      Port Alfred      ZA      26.89    -33.59            74
# 4           4          Qarchak      IR      51.57     35.44            42
#
#    Wind Speed (mph)  Cloudiness (%)  Max Temp (f)
# 0              4.45             100         24.98
# 1              9.01              29         80.71
# 2              4.61             100         65.93
# 3             20.09             100         69.94
# 4              7.16               5         52.47

# %%
export_df = df.loc[:,['City', 'Country', 'Longitude', 'Latitude', 'Humidity (%)', 'Wind Speed (mph)', 'Cloudiness (%)', 'Max Temp (f)']]
export_df.head()
# Out:
#               City Country  Longitude  Latitude  Humidity (%)  \
# 0  Severo-Kuril'sk      RU     156.12     50.68            74
# 1           Carora      VE     -70.08     10.18            51
# 2             Hilo      US    -155.09     19.73            92
# 3      Port Alfred      ZA      26.89    -33.59            74
# 4          Qarchak      IR      51.57     35.44            42
#
#    Wind Speed (mph)  Cloudiness (%)  Max Temp (f)
# 0              4.45             100         24.98
# 1              9.01              29         80.71
# 2              4.61             100         65.93
# 3             20.09             100         69.94
# 4              7.16               5         52.47

# %%
export_df.to_html('table.html')
